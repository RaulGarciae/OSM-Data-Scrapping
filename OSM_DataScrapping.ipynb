# %%
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
import osmnx as ox
import matplotlib.pyplot as plt

# %%
# Define the extent using a shapefile
extent_shp_path = 'C:/Users/garciaes/Desktop/Working/PythonTry/poland.shp'
gdf = gpd.read_file(extent_shp_path)

# %%
features = ox.features_from_polygon(gdf.geometry.values[0], tags={'amenity': 'fuel'})
# Out:
# C:\Users\garciaes\.conda\envs\ragaes\lib\site-packages\osmnx\_overpass.py:211: UserWarning: This area is 141 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)

# %%
# Convert the features to a GeoDataFrame
fuel = gpd.GeoDataFrame(features)

# %%
# Keep only desired geometry type
fuel_p= fuel[fuel.geometry.type == 'Point']

# %%
fuel_p
# Out:
#                          amenity brand brand:wikidata        brand:wikipedia  \
# element_type osmid
# node         3405358299     fuel   NaN            NaN                    NaN
#              6367541681     fuel   MPS            NaN                    NaN
#              9230972722     fuel   NaN            NaN                    NaN
#              9643958906     fuel  Moya      Q62297700                    NaN
#              1863468715     fuel   NaN            NaN                    NaN
# ...                          ...   ...            ...                    ...
#              4343009192     fuel   NaN            NaN                    NaN
#              4356185418     fuel   NaN            NaN                    NaN
#              11094443509    fuel   NaN            NaN                    NaN
#              11094443510    fuel   NaN            NaN                    NaN
#              11276617961    fuel  Avia        Q300147  de:Avia International
#
# ...

# %%
        ## In case any encoding issue appears when writing the shp remove the unnecessary columns.
#columns_to_keep = ['amenity', 'geometry', 'brand']  # Replace with your column names
#fuel_p_subset = fuel_p[columns_to_keep]

# %%
# Save the GeoDataFrame to a new shapefile
new_shapefile_path = 'C:/Users/garciaes/Desktop/Working/PythonTry/fuel_poland_all.shp'
#fuel_p_subset.to_file(new_shapefile_path, encoding='utf-8')
fuel_p.to_file(new_shapefile_path, encoding='utf-8')
# Out:
# C:\Users\garciaes\AppData\Local\Temp\ipykernel_27992\2970711969.py:4: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   fuel_p.to_file(new_shapefile_path, encoding='utf-8')
